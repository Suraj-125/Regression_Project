# %% [markdown]
# # ***Business Understanding***
# - In the following dataset we have to find the probability of admission on the basis of GRE Score, TOEFL Score, University Rating, SOP, LOR, CGPA and Resesrch.
# - We have to predict with highest accuracy by applying various ML Algorithms.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter("ignore")

# %%
df = pd.read_csv("admission.csv")
df.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 0        337          118                  4  4.5  4.5  9.65         1
# 1        324          107                  4  4.0  4.5  8.87         1
# 2        316          104                  3  3.0  3.5  8.00         1
# 3        322          110                  3  3.5  2.5  8.67         1
# 4        314          103                  2  2.0  3.0  8.21         0
#
#    Chance of Admit
# 0             0.92
# 1             0.76
# 2             0.72
# 3             0.80
# 4             0.65

# %% [markdown]
# # ***Data Understanding***

# %% [markdown]
# ***Variables Details***
# - **GRE (Graduate Record Examination)** is a standardization test which is conducted in Foreign countries to check the ability of participants. - Generally, GRE score is calculated in the terms of numerical form.
# - **TOEFL (Test of English as a Foreign Language)** is a standarized english test which is conducted for non-native English spokers. It is conducted to check the english proficiency of non-native spoker.
# - **University Rating :** This is usually a rating of universities which shows its effictiveness.
# - **LOR (Letter of Recommendation) :** This is done by the referee in the context of participants. It shows the ability, academic, work experience of the participants.
# - **SOP (Statement of Purpose) :** It is a written essay or statement delivered by participants where he/she showed their ability in details. It asks several questions regarding "Why they choose these University ?" or "Why they want to pursue their carrer from here ?"
# - **CGPA :** Marks obtained during academic.
# - **Research :** It means whether participants have done some research or written any reseach paper on their findings during researching.
# - **Chance of Admit :** It is the probabilty of selection process.

# %%
df.shape
# Out:
# (500, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          500 non-null    int64
#  1   TOEFL Score        500 non-null    int64
#  2   University Rating  500 non-null    int64
#  3   SOP                500 non-null    float64
#  4   LOR                500 non-null    float64
#  5   CGPA               500 non-null    float64
#  6   Research           500 non-null    int64
#  7   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 31.4 KB

# %%
df.isnull().sum()
# Out:
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ***Chance of Admit***

# %%
df.rename(columns = {"Chance of Admit ": "Chance of Admit"}, inplace = True)

# %%
sns.histplot(df["Chance of Admit"], kde = True)
plt.show()

# %% [markdown]
# ***GRE Score***

# %%
sns.histplot(df["GRE Score"], kde = True)
plt.show()

# %%
plt.figure(figsize = (14, 4))
sns.barplot(x = df["GRE Score"], y = df["Chance of Admit"])
plt.xticks(rotation = "vertical")
plt.show()

# %% [markdown]
# ***TOEFL Score***

# %%
sns.histplot(df["TOEFL Score"], kde = True, color = "purple")
plt.show()

# %%
plt.figure(figsize = (14, 4))
sns.barplot(x = df["TOEFL Score"], y = df["Chance of Admit"])
plt.xticks(rotation = "vertical")
plt.show()

# %% [markdown]
# ***University Rating***

# %%
df["University Rating"].unique()
# Out:
# array([4, 3, 2, 5, 1], dtype=int64)

# %%
df["University Rating"].value_counts().plot(kind = "bar")
plt.show()

# %%
plt.figure(figsize = (10, 4))
sns.barplot(x = df["University Rating"], y = df["Chance of Admit"])
plt.xticks(rotation = "vertical")
plt.show()

# %%
plt.figure(figsize = (14, 4))
sns.barplot(x = df["TOEFL Score"], y = df["University Rating"])
plt.xticks(rotation = "vertical")
plt.show()

# %%
plt.figure(figsize = (14, 4))
sns.barplot(x = df["GRE Score"], y = df["University Rating"])
plt.xticks(rotation = "vertical")
plt.show()

# %% [markdown]
# ***SOP***

# %%
sns.histplot(df["SOP"], kde = True)
plt.show()

# %%
plt.figure(figsize = (10, 4))
sns.barplot(x = df["SOP"], y = df["Chance of Admit"])
plt.xticks(rotation = "vertical")
plt.show()

# %% [markdown]
# ***LOR***

# %%
df.rename(columns = {"LOR ": "LOR"}, inplace = True)

# %%
sns.histplot(df["LOR"], kde = True)
plt.show()

# %%
plt.figure(figsize = (10, 4))
sns.barplot(x = df["LOR"], y = df["Chance of Admit"])
plt.xticks(rotation = "vertical")
plt.show()

# %%
sns.scatterplot(x = df["Chance of Admit"], y = df["TOEFL Score"], hue = df["LOR"])
plt.show()

# %% [markdown]
# ***CGPA***

# %%
sns.histplot(df["CGPA"], kde = True)
plt.show()

# %%
plt.figure(figsize = (14, 4))
sns.histplot(x = df["CGPA"], y = df["Chance of Admit"])
plt.xticks(rotation = "vertical")
plt.show()

# %%
sns.scatterplot(x = df["CGPA"], y = df["Chance of Admit"], hue = df["University Rating"])
plt.show()

# %% [markdown]
# ***Research***

# %%
df["Research"].value_counts().plot(kind = "pie", autopct = "%0.02f%%", shadow = True)
plt.title("Research Percentage")
plt.show()

# %%
plt.figure(figsize = (6, 4))
sns.barplot(x = df["Research"], y = df["Chance of Admit"])
plt.xticks(rotation = "vertical")
plt.show()

# %%
sns.scatterplot(x = df["GRE Score"], y = df["Chance of Admit"], hue = df["Research"])
plt.show()

# %%
df.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP        LOR  \
# count  500.000000   500.000000         500.000000  500.000000  500.00000
# mean   316.472000   107.192000           3.114000    3.374000    3.48400
# std     11.295148     6.081868           1.143512    0.991004    0.92545
# min    290.000000    92.000000           1.000000    1.000000    1.00000
# 25%    308.000000   103.000000           2.000000    2.500000    3.00000
# 50%    317.000000   107.000000           3.000000    3.500000    3.50000
# 75%    325.000000   112.000000           4.000000    4.000000    4.00000
# max    340.000000   120.000000           5.000000    5.000000    5.00000
#
#              CGPA    Research  Chance of Admit
# count  500.000000  500.000000        500.00000
# mean     8.576440    0.560000          0.72174
# std      0.604813    0.496884          0.14114
# min      6.800000    0.000000          0.34000
# 25%      8.127500    0.000000          0.63000
# ...

# %%
df.skew()
# Out:
# GRE Score           -0.039842
# TOEFL Score          0.095601
# University Rating    0.090295
# SOP                 -0.228972
# LOR                 -0.145290
# CGPA                -0.026613
# Research            -0.242475
# Chance of Admit     -0.289966
# dtype: float64

# %%
corr = df.corr()
corr
# Out:
#                    GRE Score  TOEFL Score  University Rating       SOP  \
# GRE Score           1.000000     0.827200           0.635376  0.613498
# TOEFL Score         0.827200     1.000000           0.649799  0.644410
# University Rating   0.635376     0.649799           1.000000  0.728024
# SOP                 0.613498     0.644410           0.728024  1.000000
# LOR                 0.524679     0.541563           0.608651  0.663707
# CGPA                0.825878     0.810574           0.705254  0.712154
# Research            0.563398     0.467012           0.427047  0.408116
# Chance of Admit     0.810351     0.792228           0.690132  0.684137
#
#                         LOR      CGPA  Research  Chance of Admit
# GRE Score          0.524679  0.825878  0.563398         0.810351
# TOEFL Score        0.541563  0.810574  0.467012         0.792228
# University Rating  0.608651  0.705254  0.427047         0.690132
# SOP                0.663707  0.712154  0.408116         0.684137
# ...

# %%
sns.heatmap(corr, cmap = "plasma" , annot = True, fmt = ".2f", linewidth = 0.5)
plt.show()

# %%
df.to_csv("admission_analyzed.csv", index = False)
